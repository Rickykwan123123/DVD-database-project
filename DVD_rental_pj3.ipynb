# %% [raw]
# 1.Time series plot with 3 countries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

c_df = pd.read_csv("/Users/siukikwan/Downloads/time-seri_3country.csv")

# %%
for i in range(0,50):

    if c_df.iloc[i]['country']=='Mexico':
        plt.bar(c_df['payment_date'],c_df['amount'], color='red', label='M')
        #plt.bar(countries_df['payment_date'],countries_df['amount'], color='red', label='M') 
        #print (i) 
    elif c_df.iloc[i]['country']=='China' and c_df.iloc[i]['country']!='Bangladesh':
        plt.bar(c_df['payment_date'],c_df['amount'], color='green', label='C')
        #print ('China')
    else :
        plt.bar(c_df['payment_date'],c_df['amount'], color='blue', label='B')
        #plt.bar(countries_df['payment_date'],countries_df['amount'], color='green', label='B') 
        #print ('not mex')


plt.xlabel('Dates')
plt.ylabel('Daily Total revenue')
plt.title(' Time-series plot showing daily total revenue for 3 countries')
#plt.xticks(rotation=45)
plt.show()

# %%
c_df
# Out:
#      country  amount                payment_date
# 0     Mexico    4.99  2007-03-21 08:17:22.996577
# 1      China    5.99  2007-03-23 05:50:28.996577
# 2      China    1.99  2007-04-29 06:06:14.996577
# 3      China    2.99  2007-04-10 15:42:53.996577
# 4      China    5.99  2007-02-15 04:27:21.996577
# ...      ...     ...                         ...
# 2023   China    2.99  2007-03-22 22:31:27.996577
# 2024  Mexico    3.99  2007-03-22 00:33:04.996577
# 2025   China    1.99  2007-03-20 15:33:28.996577
# 2026   China    4.99  2007-04-10 09:53:54.996577
# 2027  Mexico    6.99  2007-03-17 03:24:42.996577
#
# [2028 rows x 3 columns]

# %% [raw]
# 2. Revenue from different countries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

countries_df = pd.read_csv("/Users/siukikwan/Downloads/rev_diff_country.csv")
countries_df.head(10)
# Out:
#               country  country_count  total_payment
# 0               India           1422        6034.78
# 1               China           1297        5251.03
# 2       United States            869        3685.31
# 3               Japan            749        3122.51
# 4              Mexico            718        2984.82
# 5              Brazil            681        2919.19
# 6  Russian Federation            638        2765.62
# 7         Philippines            530        2219.70
# 8              Turkey            351        1498.49
# 9           Indonesia            331        1352.69

# %%
fig = plt.figure()

plt.bar(countries_df['country'],countries_df['total_payment'])
spacing = 0.1000
fig.subplots_adjust(bottom=spacing)
plt.xticks(rotation=45)

plt.xlabel('Countries')
plt.ylabel('Total revenue')
plt.title(' Total revenue from different countries')

plt.show()

# %% [raw]
# 3. top 5 rating by film name

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/siukikwan/Downloads/reve_film.csv')

# %%
df
# Out:
#       film_id  actor_id first_name                title  rental_rate  \
# 0         933        40     Johnny        Vampire Whale         4.99
# 1         989        37        Val  Working Microcosmos         4.99
# 2         412       193       Burt   Heavyweights Beast         4.99
# 3         144       180       Jeff  Chinatown Gladiator         4.99
# 4         853       189       Cuba   Stranger Strangers         4.99
# ...       ...       ...        ...                  ...          ...
# 5457      728        12       Karl      Reunion Witches         0.99
# 5458      281        11       Zero           Encino Elf         0.99
# 5459      517       178       Lisa     Lesson Cleopatra         0.99
# 5460      646       156        Fay      Outbreak Divine         0.99
# 5461      981        67    Jessica        Wolves Desire         0.99
#
#       actor_count  rank
# 0               1     1
# 1               1     1
# 2               1     1
# 3               1     1
# 4               1     1
# ...           ...   ...
# 5457            1  3603
# 5458            1  3603
# 5459            1  3603
# 5460            1  3603
# 5461            1  3603
#
# [5462 rows x 7 columns]

# %%
df[(df.columns)[6]]
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 5457    3603
# 5458    3603
# 5459    3603
# 5460    3603
# 5461    3603
# Name: rank, Length: 5462, dtype: int64

# %%
df['title']
# Out:
# 0             Vampire Whale
# 1       Working Microcosmos
# 2        Heavyweights Beast
# 3       Chinatown Gladiator
# 4        Stranger Strangers
#                ...
# 5457        Reunion Witches
# 5458             Encino Elf
# 5459       Lesson Cleopatra
# 5460        Outbreak Divine
# 5461          Wolves Desire
# Name: title, Length: 5462, dtype: object

# %% [raw]
# 4. noraml countries analyze

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

countries_df = pd.read_csv("/Users/siukikwan/Downloads/rev_diff_country.csv")
countries_df.head(20)
# Out:
#                country  country_count  total_payment
# 0                India           1422        6034.78
# 1                China           1297        5251.03
# 2        United States            869        3685.31
# 3                Japan            749        3122.51
# 4               Mexico            718        2984.82
# 5               Brazil            681        2919.19
# 6   Russian Federation            638        2765.62
# 7          Philippines            530        2219.70
# 8               Turkey            351        1498.49
# 9            Indonesia            331        1352.69
# 10           Argentina            320        1298.80
# 11             Nigeria            308        1314.92
# 12              Taiwan            290        1155.10
# 13        South Africa            254        1069.46
# 14      United Kingdom            204         850.96
# 15                Iran            204         877.96
# 16              Poland            184         786.16
# 17             Germany            176         741.24
# 18               Italy            174         753.26
# 19           Venezuela            157         632.43
